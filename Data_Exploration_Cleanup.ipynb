# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
census_data_path = "../Resources/Census_Data.csv"

census_data = pd.read_csv(census_data_path)

# Combine the data into a single dataset
#extension = 'csv'

census_data
# Out:
#     Community Area Number     Neighborhood  PERCENT OF HOUSING CROWDED  \
# 0                     1.0      Rogers Park                         7.7
# 1                     2.0       West Ridge                         7.8
# 2                     3.0           Uptown                         3.8
# 3                     4.0   Lincoln Square                         3.4
# 4                     5.0     North Center                         0.3
# ..                    ...              ...                         ...
# 73                   74.0  Mount Greenwood                         1.0
# 74                   75.0      Morgan Park                         0.8
# 75                   76.0           O'Hare                         3.6
# 76                   77.0        Edgewater                         4.1
# 77                    NaN          CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 1                               17.2                          8.8
# 2                               24.0                          8.9
# 3                               10.9                          8.2
# 4                                7.5                          5.2
# ..                               ...                          ...
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           18.2
# 1                                           20.8
# 2                                           11.8
# 3                                           13.4
# 4                                            4.5
# ..                                           ...
# 73                                           4.3
# 74                                          10.8
# 75                                          10.9
# 76                                           9.7
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                               27.5               23939            39.0
# 1                               38.5               23040            46.0
# 2                               22.2               35787            20.0
# 3                               25.5               37524            17.0
# 4                               26.2               57123             6.0
# ..                               ...                 ...             ...
# 73                              36.8               34381            16.0
# 74                              40.3               27149            30.0
# 75                              30.3               25828            24.0
# 76                              23.8               33385            19.0
# 77                              33.5               28202             NaN
#
# [78 rows x 9 columns]

# %%
environment_data_path = "../Resources/Chicago_data.csv"

environment_data = pd.read_csv(environment_data_path)

# Combine the data into a single dataset
#extension = 'csv'

environment_data
# Out:
#      COMPLAINT ID            COMPLAINT TYPE  \
# 0    DOECOMP13008  Air Pollution Work Order
# 1    DOECOMP13009  Air Pollution Work Order
# 2    DOECOMP36756  Air Pollution Work Order
# 3    DOECOMP13010  Air Pollution Work Order
# 4    DOECOMP13011  Air Pollution Work Order
# ..            ...                       ...
# 441  DOECOMP35708  Air Pollution Work Order
# 442  DOECOMP19712  Air Pollution Work Order
# 443  DOECOMP22509  Air Pollution Work Order
# 444  DOECOMP31507  Air Pollution Work Order
# 445  DOECOMP17865  Air Pollution Work Order
#
#                                 ADDRESS   Neighborhood  STREET NUMBER FROM  \
# 0          2701 E 100TH ST, CHICAGO, IL  Jeffrey Manor                2701
# 1          2701 E 100TH ST, CHICAGO, IL  Jeffrey Manor                2701
# 2          2701 E 100TH ST, CHICAGO, IL  Jeffrey Manor                2701
# 3          2701 E 100TH ST, CHICAGO, IL  Jeffrey Manor                2701
# 4          2701 E 100TH ST, CHICAGO, IL  Jeffrey Manor                2701
# ..                                  ...            ...                 ...
# 441       1330 W WINONA ST, CHICAGO, IL         Uptown                1330
# 442     411 W WISCONSIN ST, CHICAGO, IL         Depaul                 411
# 443     4500 S WOLCOTT AVE, CHICAGO, IL       New City                4500
# 444     7524 N WOLCOTT AVE, CHICAGO, IL    Rogers Park                7524
# 445  3623 W WRIGHTWOOD AVE, CHICAGO, IL   Logan Square                3623
#
#      STREET NUMBER TO DIRECTION STREET NAME STREET TYPE  INSPECTOR  \
# 0                 NaN         E       100TH          ST         27
# 1                 NaN         E       100TH          ST         27
# 2                 NaN         E       100TH          ST         77
# 3                 NaN         E       100TH          ST         69
# 4                 NaN         E       100TH          ST         77
# ..                ...       ...         ...         ...        ...
# 441               NaN         W      WINONA          ST        137
# 442               NaN         W   WISCONSIN          ST        135
# 443               NaN         S     WOLCOTT         AVE        137
# 444            7534.0         N     WOLCOTT         AVE          9
# 445               NaN         W  WRIGHTWOOD         AVE         22
#
#     COMPLAINT DATE                                   COMPLAINT DETAIL  \
# 0       01/13/2010  AGRI FINE                           PUTRID SME...
# 1       01/26/2010  AGRI FINE                           CALLER STA...
# 2       03/16/2010  AGRI FINE                           CALLER STA...
# 3       04/02/2010  AGRI FINE                           BAD TERRIB...
# 4       04/06/2010  AGRI FINE                           CALLER STA...
# ..             ...                                                ...
# 441     06/25/2010  RESIDENTIAL BLDG.                   CALLER STA...
# 442     06/29/2010  OLD CHICAGO CONSTRUCTION            WORKING HE...
# 443     05/17/2010  7 D CONSTRUCTION                    FACILITY T...
# 444     10/05/2010  BUSINESS                            CALLER STA...
# 445     10/12/2010  RESIDENTIAL BLDG.                   CALLER STA...
#
#                                         INSPECTION LOG  \
# 0    MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 1    MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 2    MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 3    MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 4    MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# ..                                                 ...
# 441  MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 442  MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 443  MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 444  MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
# 445  MORE INFORMATION MAY BE AVAILABLE IN THE CDPH ...
#
#                        DATA SOURCE Modified Date  LATITUDE  LONGITUDE  \
# 0    HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 1    HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 2    HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 3    HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 4    HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# ..                             ...           ...       ...        ...
# 441  HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 442  HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 443  HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 444  HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
# 445  HISTORIC DEPT. OF ENVIRONMENT    01/01/2012       NaN        NaN
#
#      LOCATION
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 441       NaN
# 442       NaN
# 443       NaN
# 444       NaN
# 445       NaN
#
# [446 rows x 18 columns]

# %%
combined_data = pd.merge(environment_data, census_data, on="Neighborhood")
combined_data
# Out:
#      COMPLAINT ID            COMPLAINT TYPE  \
# 0    DOECOMP29999  Air Pollution Work Order
# 1    DOECOMP29998  Air Pollution Work Order
# 2    DOECOMP30000  Air Pollution Work Order
# 3     DOECOMP1839  Air Pollution Work Order
# 4     DOECOMP8772  Air Pollution Work Order
# ..            ...                       ...
# 243  DOECOMP31879  Air Pollution Work Order
# 244  DOECOMP32306  Air Pollution Work Order
# 245  DOECOMP32307  Air Pollution Work Order
# 246  DOECOMP35677  Air Pollution Work Order
# 247  DOECOMP31507  Air Pollution Work Order
#
#                                    ADDRESS    Neighborhood  \
# 0              700 E 107TH ST, CHICAGO, IL         Pullman
# 1              700 E 107TH ST, CHICAGO, IL         Pullman
# 2              700 E 107TH ST, CHICAGO, IL         Pullman
# 3    11436 S FORRESTVILLE AVE, CHICAGO, IL         Pullman
# 4             2019 W 111TH ST, CHICAGO, IL     Morgan Park
# ..                                     ...             ...
# 243         7600 S SEELEY AVE, CHICAGO, IL  Auburn Gresham
# 244      7901 S WENTWORTH AVE, CHICAGO, IL  Auburn Gresham
# 245      7901 S WENTWORTH AVE, CHICAGO, IL  Auburn Gresham
# 246      13000 S TORRENCE AVE, CHICAGO, IL   South Deering
# 247        7524 N WOLCOTT AVE, CHICAGO, IL     Rogers Park
#
#      STREET NUMBER FROM  STREET NUMBER TO DIRECTION   STREET NAME STREET TYPE  \
# 0                   700               NaN         E         107TH          ST
# 1                   700               NaN         E         107TH          ST
# 2                   700               NaN         E         107TH          ST
# 3                 11436               NaN         S  FORRESTVILLE         AVE
# 4                  2019               NaN         W         111TH          ST
# ..                  ...               ...       ...           ...         ...
# 243                7600               NaN         S        SEELEY         AVE
# 244                7901               NaN         S     WENTWORTH         AVE
# 245                7901               NaN         S     WENTWORTH         AVE
# 246               13000               NaN         S      TORRENCE         AVE
# 247                7524            7534.0         N       WOLCOTT         AVE
#
#      INSPECTOR  ... LONGITUDE LOCATION Community Area Number  \
# 0           77  ...       NaN      NaN                  50.0
# 1          122  ...       NaN      NaN                  50.0
# 2           82  ...       NaN      NaN                  50.0
# 3           77  ...       NaN      NaN                  50.0
# 4          122  ...       NaN      NaN                  75.0
# ..         ...  ...       ...      ...                   ...
# 243         81  ...       NaN      NaN                  71.0
# 244         82  ...       NaN      NaN                  71.0
# 245         82  ...       NaN      NaN                  71.0
# 246         81  ...       NaN      NaN                  51.0
# 247          9  ...       NaN      NaN                   1.0
#
#     PERCENT OF HOUSING CROWDED PERCENT HOUSEHOLDS BELOW POVERTY  \
# 0                          1.5                             21.6
# 1                          1.5                             21.6
# 2                          1.5                             21.6
# 3                          1.5                             21.6
# 4                          0.8                             13.2
# ..                         ...                              ...
# 243                        4.0                             27.6
# 244                        4.0                             27.6
# 245                        4.0                             27.6
# 246                        4.0                             29.2
# 247                        7.7                             23.6
#
#      PERCENT AGED 16+ UNEMPLOYED  \
# 0                           22.8
# 1                           22.8
# 2                           22.8
# 3                           22.8
# 4                           15.0
# ..                           ...
# 243                         28.3
# 244                         28.3
# 245                         28.3
# 246                         16.3
# 247                          8.7
#
#      PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                            13.1
# 1                                            13.1
# 2                                            13.1
# 3                                            13.1
# 4                                            10.8
# ..                                            ...
# 243                                          18.5
# 244                                          18.5
# 245                                          18.5
# 246                                          21.0
# 247                                          18.2
#
#      PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                                38.6               20588            51.0
# 1                                38.6               20588            51.0
# 2                                38.6               20588            51.0
# 3                                38.6               20588            51.0
# 4                                40.3               27149            30.0
# ..                                ...                 ...             ...
# 243                              41.9               15528            74.0
# 244                              41.9               15528            74.0
# 245                              41.9               15528            74.0
# 246                              39.5               14685            65.0
# 247                              27.5               23939            39.0
#
# [248 rows x 26 columns]

# %%
combined_data.to_csv("../Resources/merged_data.csv")
combined_data.head()
# Out:
#    COMPLAINT ID            COMPLAINT TYPE  \
# 0  DOECOMP29999  Air Pollution Work Order
# 1  DOECOMP29998  Air Pollution Work Order
# 2  DOECOMP30000  Air Pollution Work Order
# 3   DOECOMP1839  Air Pollution Work Order
# 4   DOECOMP8772  Air Pollution Work Order
#
#                                  ADDRESS Neighborhood  STREET NUMBER FROM  \
# 0            700 E 107TH ST, CHICAGO, IL      Pullman                 700
# 1            700 E 107TH ST, CHICAGO, IL      Pullman                 700
# 2            700 E 107TH ST, CHICAGO, IL      Pullman                 700
# 3  11436 S FORRESTVILLE AVE, CHICAGO, IL      Pullman               11436
# 4           2019 W 111TH ST, CHICAGO, IL  Morgan Park                2019
#
#    STREET NUMBER TO DIRECTION   STREET NAME STREET TYPE  INSPECTOR  ...  \
# 0               NaN         E         107TH          ST         77  ...
# 1               NaN         E         107TH          ST        122  ...
# 2               NaN         E         107TH          ST         82  ...
# 3               NaN         S  FORRESTVILLE         AVE         77  ...
# 4               NaN         W         111TH          ST        122  ...
#
#   LONGITUDE LOCATION Community Area Number PERCENT OF HOUSING CROWDED  \
# 0       NaN      NaN                  50.0                        1.5
# 1       NaN      NaN                  50.0                        1.5
# 2       NaN      NaN                  50.0                        1.5
# 3       NaN      NaN                  50.0                        1.5
# 4       NaN      NaN                  75.0                        0.8
#
#   PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                             21.6                         22.8
# 1                             21.6                         22.8
# 2                             21.6                         22.8
# 3                             21.6                         22.8
# 4                             13.2                         15.0
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          13.1
# 1                                          13.1
# 2                                          13.1
# 3                                          13.1
# 4                                          10.8
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              38.6               20588            51.0
# 1                              38.6               20588            51.0
# 2                              38.6               20588            51.0
# 3                              38.6               20588            51.0
# 4                              40.3               27149            30.0
#
# [5 rows x 26 columns]
