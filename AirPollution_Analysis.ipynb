# %% [markdown]
# # **Air Pollution in Chicago, CY2010**
# ---
# ## Setup

# %%
# Dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os
import time

# Import API key
from config import gkey

# %% [markdown]
# ## **Question 1: Which Chicago neighborhoods submitted the highest number of air pollution complaints in 2010?**
# -----

# %% [markdown]
# ### Bar Chart of Air Pollution Complaints by Neighborhood

# %%
# Caroline to add

# %% [markdown]
# ### Heat Map of Air Pollution Complaints by Neighborhood

# %%
# Load merged dataset into Jupyter Notebook
merged_dataset = "Resources/merged_data.csv"
air_pollution_df = pd.read_csv(merged_dataset)
# Create dataframe showing number of complaints by neighborhood in descending order 
neighborhood = air_pollution_df.groupby(["Neighborhood"])
complaint_count = neighborhood["COMPLAINT ID"].count()
neighborhood_df = pd.DataFrame({"Number of Complaints": complaint_count})
neighborhood_df = neighborhood_df.sort_values(["Number of Complaints"], ascending = False).reset_index()
# Add columns to neighborhood_df for location data
neighborhood_df["Region"] = neighborhood_df["Neighborhood"].astype(str) + ", Chicago, IL"
neighborhood_df["Latitude"] = ""
neighborhood_df["Longitude"] = ""
# Print dataframe header for reference
neighborhood_df.head()
# Out:
#      Neighborhood  Number of Complaints                       Region Latitude  \
# 0  West Englewood                    14  West Englewood, Chicago, IL
# 1          Uptown                    12          Uptown, Chicago, IL
# 2        New City                     9        New City, Chicago, IL
# 3         Chatham                     9         Chatham, Chicago, IL
# 4            Loop                     9            Loop, Chicago, IL
#
#   Longitude
# 0
# 1
# 2
# 3
# 4

# %%
print("---------------------------")
print("Beginning data retrieval...")
print("---------------------------")
# Build partial query URL
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
params = {"key" : gkey}
# Iterate through rows of neighborhood_df 
for index, row in neighborhood_df.iterrows():
    # Get address from neighborhood_df
    search_address = row["Region"]
    # Add keyword to params dictionary
    params["address"] = search_address
    # Assemble URL and make API request
    print(f"Retrieving Results for Index {index}: {search_address}.")
    response = requests.get(base_url, params = params).json()
    # Extract location coordinates and save to neighborhood_df
    neighborhood_data = response
    try:
        neighborhood_df.loc[index, "Latitude"] = neighborhood_data["results"][0]["geometry"]["location"]["lat"]
        neighborhood_df.loc[index, "Longitude"] = neighborhood_data["results"][0]["geometry"]["location"]["lng"]
    # Skip row if neighborhood not found
    except (KeyError, IndexError):
        print("Neighborhood not found. Skipping...")
    print("-------------")
    # Set 5s timer for API requests
    time.sleep(5)
print("---------------------------")
print("Data retrieval complete.")
print("---------------------------")
# Out:
# ---------------------------
# Beginning data retrieval...
# ---------------------------
# Retrieving Results for Index 0: West Englewood, Chicago, IL.
# -------------
# Retrieving Results for Index 1: Uptown, Chicago, IL.
# -------------
# Retrieving Results for Index 2: New City, Chicago, IL.
# -------------
# Retrieving Results for Index 3: Chatham, Chicago, IL.
# -------------
# Retrieving Results for Index 4: Loop, Chicago, IL.
# -------------
# Retrieving Results for Index 5: Dunning, Chicago, IL.
# -------------
# Retrieving Results for Index 6: Logan Square, Chicago, IL.
# -------------
# Retrieving Results for Index 7: Near West Side, Chicago, IL.
# -------------
# Retrieving Results for Index 8: Lake View, Chicago, IL.
# -------------
# Retrieving Results for Index 9: South Shore, Chicago, IL.
# -------------
# Retrieving Results for Index 10: West Garfield Park, Chicago, IL.
# -------------
# Retrieving Results for Index 11: Irving Park, Chicago, IL.
# -------------
# Retrieving Results for Index 12: Greater Grand Crossing, Chicago, IL.
# -------------
# Retrieving Results for Index 13: Norwood Park, Chicago, IL.
# -------------
# Retrieving Results for Index 14: Lincoln Park, Chicago, IL.
# -------------
# Retrieving Results for Index 15: Edgewater, Chicago, IL.
# -------------
# Retrieving Results for Index 16: Lower West Side, Chicago, IL.
# -------------
# Retrieving Results for Index 17: South Chicago, Chicago, IL.
# -------------
# Retrieving Results for Index 18: Jefferson Park, Chicago, IL.
# -------------
# Retrieving Results for Index 19: South Lawndale, Chicago, IL.
# -------------
# Retrieving Results for Index 20: Douglas, Chicago, IL.
# -------------
# Retrieving Results for Index 21: Avondale, Chicago, IL.
# -------------
# Retrieving Results for Index 22: Hyde Park, Chicago, IL.
# -------------
# Retrieving Results for Index 23: Roseland, Chicago, IL.
# -------------
# Retrieving Results for Index 24: Pullman, Chicago, IL.
# -------------
# Retrieving Results for Index 25: Near South Side, Chicago, IL.
# -------------
# Retrieving Results for Index 26: Near North Side, Chicago, IL.
# -------------
# Retrieving Results for Index 27: Albany Park, Chicago, IL.
# -------------
# Retrieving Results for Index 28: Englewood, Chicago, IL.
# -------------
# Retrieving Results for Index 29: Ashburn, Chicago, IL.
# -------------
# Retrieving Results for Index 30: Auburn Gresham, Chicago, IL.
# -------------
# Retrieving Results for Index 31: Austin, Chicago, IL.
# -------------
# Retrieving Results for Index 32: East Garfield Park, Chicago, IL.
# -------------
# Retrieving Results for Index 33: Beverly, Chicago, IL.
# -------------
# Retrieving Results for Index 34: Brighton Park, Chicago, IL.
# -------------
# Retrieving Results for Index 35: Woodlawn, Chicago, IL.
# -------------
# Retrieving Results for Index 36: Lincoln Square, Chicago, IL.
# -------------
# Retrieving Results for Index 37: Gage Park, Chicago, IL.
# -------------
# Retrieving Results for Index 38: McKinley Park, Chicago, IL.
# -------------
# Retrieving Results for Index 39: North Center, Chicago, IL.
# -------------
# Retrieving Results for Index 40: West Town, Chicago, IL.
# -------------
# Retrieving Results for Index 41: Belmont Cragin, Chicago, IL.
# -------------
# Retrieving Results for Index 42: Kenwood, Chicago, IL.
# -------------
# Retrieving Results for Index 43: Clearing, Chicago, IL.
# -------------
# Retrieving Results for Index 44: Hegewisch, Chicago, IL.
# -------------
# Retrieving Results for Index 45: Calumet Heights, Chicago, IL.
# -------------
# Retrieving Results for Index 46: Archer Heights, Chicago, IL.
# -------------
# Retrieving Results for Index 47: Chicago Lawn, Chicago, IL.
# -------------
# Retrieving Results for Index 48: Rogers Park, Chicago, IL.
# -------------
# Retrieving Results for Index 49: Bridgeport, Chicago, IL.
# -------------
# Retrieving Results for Index 50: South Deering, Chicago, IL.
# -------------
# Retrieving Results for Index 51: East Side, Chicago, IL.
# -------------
# Retrieving Results for Index 52: Avalon Park, Chicago, IL.
# -------------
# Retrieving Results for Index 53: Mount Greenwood, Chicago, IL.
# -------------
# Retrieving Results for Index 54: Morgan Park, Chicago, IL.
# -------------
# Retrieving Results for Index 55: Edison Park, Chicago, IL.
# -------------
# Retrieving Results for Index 56: West Lawn, Chicago, IL.
# -------------
# Retrieving Results for Index 57: West Pullman, Chicago, IL.
# -------------
# ---------------------------
# Data retrieval complete.
# ---------------------------

# %%
# Print neighborhood_df to ensure location data has updated
neighborhood_df
# Out:
#               Neighborhood  Number of Complaints  \
# 0           West Englewood                    14
# 1                   Uptown                    12
# 2                 New City                     9
# 3                  Chatham                     9
# 4                     Loop                     9
# 5                  Dunning                     8
# 6             Logan Square                     7
# 7           Near West Side                     7
# 8                Lake View                     7
# 9              South Shore                     7
# 10      West Garfield Park                     7
# 11             Irving Park                     6
# 12  Greater Grand Crossing                     6
# 13            Norwood Park                     6
# 14            Lincoln Park                     6
# 15               Edgewater                     6
# 16         Lower West Side                     6
# 17           South Chicago                     5
# 18          Jefferson Park                     5
# 19          South Lawndale                     5
# 20                 Douglas                     5
# 21                Avondale                     5
# 22               Hyde Park                     5
# 23                Roseland                     4
# 24                 Pullman                     4
# 25         Near South Side                     4
# 26         Near North Side                     4
# 27             Albany Park                     4
# 28               Englewood                     4
# 29                 Ashburn                     4
# 30          Auburn Gresham                     4
# 31                  Austin                     4
# 32      East Garfield Park                     4
# 33                 Beverly                     4
# 34           Brighton Park                     4
# 35                Woodlawn                     3
# 36          Lincoln Square                     3
# 37               Gage Park                     3
# 38           McKinley Park                     3
# 39            North Center                     2
# 40               West Town                     2
# 41          Belmont Cragin                     2
# 42                 Kenwood                     2
# 43                Clearing                     2
# 44               Hegewisch                     2
# 45         Calumet Heights                     2
# 46          Archer Heights                     1
# 47            Chicago Lawn                     1
# 48             Rogers Park                     1
# 49              Bridgeport                     1
# 50           South Deering                     1
# 51               East Side                     1
# 52             Avalon Park                     1
# 53         Mount Greenwood                     1
# 54             Morgan Park                     1
# 55             Edison Park                     1
# 56               West Lawn                     1
# 57            West Pullman                     1
#
#                                  Region   Latitude  Longitude
# 0           West Englewood, Chicago, IL  41.779516 -87.664291
# 1                   Uptown, Chicago, IL   41.96654  -87.65334
# 2                 New City, Chicago, IL  41.806677 -87.667976
# 3                  Chatham, Chicago, IL   41.74012 -87.614636
# 4                     Loop, Chicago, IL  41.878635 -87.625055
# 5                  Dunning, Chicago, IL   41.94526    -87.807
# 6             Logan Square, Chicago, IL   41.92306 -87.709291
# 7           Near West Side, Chicago, IL  41.866846 -87.666409
# 8                Lake View, Chicago, IL  41.939781 -87.658927
# 9              South Shore, Chicago, IL  41.758993 -87.570026
# 10      West Garfield Park, Chicago, IL  41.877935 -87.730489
# 11             Irving Park, Chicago, IL  41.953822 -87.719287
# 12  Greater Grand Crossing, Chicago, IL  41.765703 -87.615251
# 13            Norwood Park, Chicago, IL  41.985809 -87.806912
# 14            Lincoln Park, Chicago, IL   41.92547 -87.648778
# 15               Edgewater, Chicago, IL  41.983685 -87.660114
# 16         Lower West Side, Chicago, IL  41.852333 -87.666016
# 17           South Chicago, Chicago, IL  41.739686 -87.554418
# 18          Jefferson Park, Chicago, IL  41.982504   -87.7704
# 19          South Lawndale, Chicago, IL  41.844527 -87.705045
# 20                 Douglas, Chicago, IL  41.834732 -87.620613
# 21                Avondale, Chicago, IL  41.939347  -87.70266
# 22               Hyde Park, Chicago, IL  41.794767 -87.591675
# 23                Roseland, Chicago, IL  41.710834 -87.623583
# 24                 Pullman, Chicago, IL  41.707617 -87.594188
# 25         Near South Side, Chicago, IL    41.8608  -87.62572
# 26         Near North Side, Chicago, IL   41.90391 -87.631463
# 27             Albany Park, Chicago, IL  41.968327 -87.728028
# 28               Englewood, Chicago, IL  41.775305 -87.641642
# 29                 Ashburn, Chicago, IL   41.74969 -87.712007
# 30          Auburn Gresham, Chicago, IL  41.743377 -87.656199
# 31                  Austin, Chicago, IL  41.894871 -87.765401
# 32      East Garfield Park, Chicago, IL  41.881035 -87.701185
# 33                 Beverly, Chicago, IL   41.71712  -87.67618
# 34           Brighton Park, Chicago, IL  41.817084 -87.699427
# 35                Woodlawn, Chicago, IL   41.78058 -87.591535
# 36          Lincoln Square, Chicago, IL  41.968682 -87.688965
# 37               Gage Park, Chicago, IL   41.79352 -87.703578
# 38           McKinley Park, Chicago, IL  41.831618 -87.672907
# 39            North Center, Chicago, IL  41.946745 -87.688257
# 40               West Town, Chicago, IL  41.893595 -87.672167
# 41          Belmont Cragin, Chicago, IL  41.931294 -87.766255
# 42                 Kenwood, Chicago, IL  41.809477 -87.593266
# 43                Clearing, Chicago, IL  41.777964 -87.769056
# 44               Hegewisch, Chicago, IL  41.655496 -87.545862
# 45         Calumet Heights, Chicago, IL  41.729831 -87.570476
# 46          Archer Heights, Chicago, IL    41.8079 -87.723585
# 47            Chicago Lawn, Chicago, IL  41.771839 -87.693179
# 48             Rogers Park, Chicago, IL  42.012629 -87.674588
# 49              Bridgeport, Chicago, IL  41.836416 -87.648661
# 50           South Deering, Chicago, IL  41.673658 -87.575337
# 51               East Side, Chicago, IL  41.707994 -87.535173
# 52             Avalon Park, Chicago, IL  41.744202 -87.585576
# 53         Mount Greenwood, Chicago, IL   41.69159 -87.700805
# 54             Morgan Park, Chicago, IL   41.68753 -87.669165
# 55             Edison Park, Chicago, IL  42.003519 -87.817149
# 56               West Lawn, Chicago, IL  41.778663 -87.722794
# 57            West Pullman, Chicago, IL  41.677851 -87.641952

# %%
# Configure gmaps
gmaps.configure(api_key = gkey)
# Store latitude and longitude in locations
locations = neighborhood_df[["Latitude", "Longitude"]]
complaints = neighborhood_df["Number of Complaints"].astype(float)
# Plot heatmap
complaints_heatmap = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights = complaints, dissipating = False, max_intensity = 14, point_radius = 0.02)
# Add layer
complaints_heatmap.add_layer(heat_layer)
# Display figure
complaints_heatmap
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## **Question 2: Did the number of air pollution complaints vary by neighborhood income level?**
# -----

# %% [markdown]
# ### Boxplot of Complaints: Low Income vs High Income

# %%
# Nicole to share boxplot

# %% [markdown]
# ### Scatter Plot of Complaints by Income Level

# %%
# Caroline to share scatterplot + linear regression

# %% [markdown]
# ## **Question 3: Did the number of air pollution complaints vary by minority communities?**
# -----

# %% [markdown]
# ### Races by Neighborhood

# %%
# Devyn to share

# %% [markdown]
# ### Line Graph by Race

# %%
# Devyn to share
